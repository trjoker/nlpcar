# %%
import pandas as pd
import re
import jieba

# %%
class CleanData:
    # 要去除的固定词
    unUselessWords = ['[语音]', '[图片]']
    unUselessSymbol = '[`~!@#$^&*()_\\-+=|{}\':;\',\\[\\]<>/?~！@#￥……&*（）——+|{}【】‘；：”“’。，、？]'
    web_reg = r'(https?|ftp|file)://[-A-Za-z0-9+&@#/%?=~_|!:,.;]+[-A-Za-z0-9+&@#/%=~_|]'
    taobao_reg = r"￥[A-Za-z0-9]+￥"

    @staticmethod
    def cleanData(string):
        # 去除无用关键词
        string = CleanData.removeUselessWords(string)
        # 去除网址
        string = CleanData.removeWeb(string)
        # 去除淘口令
        string = CleanData.removeTaobao(string)
        # 去除特殊符号保留 符号.
        string = CleanData.removeSymbols(string)
        return string

    @staticmethod
    def removeUselessWords(string):
        for word in CleanData.unUselessWords:
            if (word in string):
                string = string.replace(word, ' ')
        return string

    # 去除网址
    @staticmethod
    def removeWeb(string):
        pattern = re.compile(CleanData.web_reg)
        return pattern.sub(" ", string)

    # 去除手淘链接例如 ￥orIk0ITYkCs￥
    @staticmethod
    def removeTaobao(string):
        pattern = re.compile(CleanData.taobao_reg)
        return pattern.sub("", string)

    # 去除特殊符号 ? ,| 等但是保留.
    @staticmethod
    def removeSymbols(string):
        pattern = re.compile(CleanData.unUselessSymbol)
        return pattern.sub(" ", string)

# %%
trianData = 'datas/AutoMaster_TrainSet.csv'
testData = 'datas/AutoMaster_TestSet.csv'

# %%
dataFrame = pd.read_csv(trianData, encoding="UTF-8")
# 获取所需列
dataFrame = dataFrame.iloc[:, 1:6]
# 将所有列拼接成一个list
text_list = []
for index, row in dataFrame.iteritems():
    text_list.extend(dataFrame[index].tolist())

# %%
text_list[300000:300020]
# Out:
# ['技师说：您就是跑起来嗡嗡嗡的声音大？',
#  '技师说：不需要更换的，全合成机油，建议一年换一次|技师说：爱车跑了多少公里了|车主说：两万|车主说：两万公里我都保养四次了|车主说：三次美孚一号|技师说：5000保养一次|车主说：一次是送的保养|技师说：美孚一号完全可以跑10000公里换一次|车主说：三千公里保养送的|车主说：8000换的美孚一号|技师说：首保3000做的|车主说：然后一万三做的第三次|车主说：现在公里数没到时间到了|技师说：我说这个机油不用5000换油一次|技师说：可以延长换油公里数|技师说：上次换油是几月份|车主说：大概七月份|技师说：上次保养后跑了多少公里|车主说：到现在大概三四千公里|技师说：不需要|技师说：不需要换油|车主说：那到什么时候换？|技师说：这款机油建议跑7500公里换油一次|技师说：最合适|技师说：5000换油太浪费了|车主说：时间呢？|车主说：一年？|车主说：我刚刚打电话问了，上次离现在已经八个月了，公里数是六千不到|技师说：你问的是4s|车主说：嗯|车主说：大概八个月的时间了|技师说：4s都是这种套路|技师说：全合成机油完全可以一年或者10000公里换油一次|车主说：没有，我能确定是的，时间八个月，14000保的|车主说：哦，那我就在跑跑|技师说：可以的|车主说：嗯，谢谢|技师说：客气了|车主说：全合成就是一年可以的是吗？|技师说：是的|车主说：好|车主说：谢谢',
 这个是原理图 技师说 这个阀内部控制通断的  车主说 那麻烦您明天拍张实物照片给我 技师说 可以的 技师说   技师说   技师说 只有一个黄色的垫子 技师说 这是车子上的 车主说 里面是有一个弹簧吗  车主说 内部是有一个弹簧吗  技师说 是的  技师说   技师说   技师说   技师说 在车上不好拆 费劲了   车主说 谢谢 技师说 不客气 车主说 您可以把那个弹簧单独拍张照片给我吗  技师说 车子走了 就拍了这几张 就是个细簧',
#  '技师说 建议检查一下火花塞 您车多少公里了 ',
#  '技师说 质量好的价格在350左右 技师说   技师说 建议更换原厂或者法雷奥 车主说 原厂的多钱 技师说 450左右 车主说 代手工呢 技师说 没有 比较好换',
#  '技师说 你好 不会是保险丝盒烧了 应该是收音机电容烧了  车主说 我测过线上没电 车主说 没打火前12v 车主说 打火后 没电了  技师说 最好用试灯量 试下保险丝有没有亮灯  车主说 没量 如果保险丝盒烧了能修吗 还是换新的 车主说 原保险丝坏了 他用铜丝连的 拆下来铜丝没烧断 但啪的一声 肯定是什么烧坏了  技师说 可以维修 用线焊接  技师说 锡焊',
#  '技师说 您好 蓄电池亏电严重 需要拆下蓄电池小电流充电 最佳 例如45安时 10安培电流充电4.5小时SOC100% 此时充电完毕 电压不低于12.6伏  技师说 拆下蓄电池充电最佳 或是启动另一台车 搭电 也可以排除故障 正极对正极 负极对负极  车主说 充了一个小时拧钥匙还是没反应仪表盘灯还是不亮 车主说 充了一个小时拧钥匙还是没反应仪表盘灯还是不亮']

# %%
text = ''
for a in text_list:
    text += a
    text += ' '

# %%
print(len(text))
# Out:
# 28746377

# %%
cut_text= jieba.cut(text)

# %%
cut_text
# Out:
# <generator object Tokenizer.cut at 0x000001F9282269C8>

# %%
for x in cut_text:
    print(x)

# %%
def get_stopwords_list():
    stopwords = [line.strip() for line in open('datas/stopwords.txt',encoding='UTF-8').readlines()]
    return stopwords

# %%
valid_text = [t for t in cut_text if t.strip() and t not in get_stopwords_list()]

# %%
def get_vocab(texts):
    vocab_set = set(texts)
    vocab_to_int = {word: index for index, word in enumerate(vocab_set)}
    with open('datas/VocabToInt.txt', 'w+', encoding='UTF-8') as f:
        for k, v in vocab_to_int.items():
            f.write(str(k) + ' ' + str(v) + '\n')
    return vocab_to_int

# %%
get_vocab(valida_text)
# Out:
# {'慢吞吞': 0,
#  '便利': 1,
#  '拧下来': 2,
#  '上山': 3,
#  '带个': 4,
#  '一闪刚': 5,
#  '保险金': 6,
#  '搞懂': 7,
#  '码在查': 8,
#  '装逼带': 9,
#  'AfW': 10,
#  '恩小': 11,
#  '管时': 12,
#  '抖下': 13,
#  '然後空': 14,
#  'Ac': 15,
#  '费事': 16,
#  '次火': 17,
#  '其实不然': 18,
#  '油才亮': 19,
#  '支管脏': 20,
#  '不吸合': 21,
#  '98': 22,
#  '边灯': 23,
#  '或烂': 24,
#  's6': 25,
#  '昨儿': 26,
#  '角钱': 27,
#  '20171.4': 28,
#  '轮收': 29,
#  '金堂': 30,
#  '跳火时': 31,
#  '遮上': 32,
#  '少换': 33,
#  '锁后': 34,
#  '纵列': 35,
#  '反冲': 36,
#  '空气密度': 37,
#  '簿': 38,
#  '不影': 39,
#  'dsg7': 40,
#  '键后': 41,
#  '会解': 42,
#  '求牛人': 43,
#  '全无': 44,
#  '计设': 45,
#  '支起车': 46,
#  '太濫': 47,
#  '索性': 48,
#  '這時': 49,
#  '爱要': 50,
#  '一分钟': 51,
#  '里流': 52,
#  '档次': 53,
#  '机工': 54,
#  '时规用': 55,
#  '发没': 56,
#  '亮丽': 57,
#  '看主': 58,
#  '冷得': 59,
#  '猜解': 60,
#  '审证': 61,
#  '悦动前': 62,
#  '请速换': 63,
#  '710': 64,
#  '锁片': 65,
#  '却发': 66,
#  'E1': 67,
#  '调托': 68,
#  '油笨': 69,
#  '每周日': 70,
#  '啥时候': 71,
#  '点瞎收': 72,
#  '一拳': 73,
#  '电脑班': 74,
#  '刚着': 75,
#  '大保时': 76,
#  '大排量': 77,
#  '黑漆漆': 78,
#  '那因': 79,
#  '美关': 80,
#  '揭阳': 81,
#  '猝不及防': 82,
#  '色泽': 83,
#  '先空': 84,
#  '偿': 85,
#  '门及': 86,
#  '前护': 87,
#  '可会': 88,
#  '接应': 89,
#  '多问': 90,
#  '上周三': 91,
#  '爆竹': 92,
#  '嘴用': 93,
#  'F3R473QB': 94,
#  '底垫': 95,
#  '认可度': 96,
#  '配过': 97,
#  '940': 98,
#  '火山': 99,
#  '泡能': 100,
#  '一休': 101,
#  '咋关': 102,
#  '前气': 103,
#  '试开': 104,
#  '净化器': 105,
#  '量子': 106,
#  '后退': 107,
#  '出少少': 108,
#  '6.3': 109,
#  '零六': 110,
#  '烤平': 111,
#  '根电': 112,
#  '埃尼': 113,
#  '12V120': 114,
#  '118435': 115,
#  '感热': 116,
#  '淘一': 117,
#  'D6': 118,
#  '小鼓': 119,
#  'CT': 120,
#  '呃': 121,
#  '再冲': 122,
#  '通外': 123,
#  '与否': 124,
#  '重喷': 125,
#  '换难': 126,
#  '哈说': 127,
#  '棒棒': 128,
#  '选车': 129,
#  '4jB1': 130,
#  '新泵泵': 131,
#  '帘布': 132,
#  '真愁': 133,
#  '千传': 134,
#  '诗图': 135,
#  '改动': 136,
#  '人坑': 137,
#  'fault': 138,
#  '一碰': 139,
#  '六秒': 140,
#  '轴封': 141,
#  '主打产品': 142,
#  '喀嚓': 143,
#  '那小块': 144,
#  '紧急灯': 145,
#  '2O1O': 146,
#  '过十台': 147,
#  '飙完': 148,
#  '折旧': 149,
#  '换不带': 150,
#  '0.83': 151,
#  '强中自有强中手': 152,
#  '没谱': 153,
#  '数显': 154,
#  '威开': 155,
#  '亮些': 156,
#  '要息屏': 157,
#  '6373e3': 158,
#  '光挂': 159,
#  '答到': 160,
#  '台开': 161,
#  'st': 162,
#  '5772': 163,
#  '付近': 164,
#  'Dodge': 165,
#  'IPADmini': 166,
#  '320lim': 167,
#  '丁基胶': 168,
#  '油扶子': 169,
#  '线响': 170,
#  'P1C14': 171,
#  '检车线': 172,
#  '地挡': 173,
#  '梁只': 174,
#  '忍': 175,
#  '及时处理': 176,
#  '连非': 177,
#  '澳洲': 178,
#  '或能': 179,
#  '五伏电': 180,
#  '中设': 181,
#  '减档会': 182,
#  '沁片': 183,
#  '机整': 184,
#  '带给': 185,
#  '品牌形象': 186,
#  '房车': 187,
#  '杂志': 188,
#  '铺': 189,
#  '炮筒': 190,
#  '量灯': 191,
#  '应比': 192,
#  '路虎修': 193,
#  'WBAKB2102AC404797': 194,
#  '泥雨': 195,
#  'p1613': 196,
#  '6204': 197,
#  '4111': 198,
#  '梁': 199,
#  '昌道': 200,
#  '轴盖': 201,
#  '人摇晕': 202,
#  '0': 203,
#  '荣誉': 204,
#  '辛苦': 205,
#  '订立': 206,
#  '扣不开': 207,
#  '放开手': 208,
#  '机原车': 209,
#  '普及': 210,
#  '台俩': 211,
#  '座漏': 212,
#  '老马': 213,
#  '可牛': 214,
#  '霉': 215,
#  '以新': 216,
#  'WindowsCE': 217,
#  '耶油': 218,
#  '进口车': 219,
#  '儿注': 220,
#  '269k': 221,
#  '片见': 222,
#  '原因': 223,
#  '尾朝下': 224,
#  '屏坏': 225,
#  '要会读': 226,
#  '稍稍': 227,
#  '灭车声': 228,
#  '不够格': 229,
#  '挡缓': 230,
#  '看金': 231,
#  '瓦上': 232,
#  '留在': 233,
#  '黄': 234,
#  '车大架': 235,
#  '两时': 236,
#  '过网': 237,
#  '报复': 238,
#  '防液': 239,
#  '几副': 240,
#  '2032': 241,
#  '2a53': 242,
#  'VX': 243,
#  '仰翻': 244,
#  'Edinburgh': 245,
#  '贵点': 246,
#  '前氧先放': 247,
#  '比碟刹': 248,
#  '混加过': 249,
#  '新档': 250,
#  '款智享': 251,
#  '泡面': 252,
#  '升满': 253,
#  '它主驾': 254,
#  '三立': 255,
#  '光高': 256,
#  'TSD4': 257,
#  '敢情': 258,
#  '中收': 259,
#  'yes': 260,
#  '不水': 261,
#  '正本': 262,
#  '石垫': 263,
#  '车订': 264,
#  '电动门': 265,
#  '先连': 266,
#  '一扇门': 267,
#  '长扣': 268,
#  '保质': 269,
#  'SACHS': 270,
#  '别缺': 271,
#  '数成': 272,
#  '25800': 273,
#  '广汽传': 274,
#  '满轮': 275,
#  '一罐': 276,
#  'hm60756': 277,
#  '做生意': 278,
#  '打快': 279,
#  '接冰': 280,
#  '300W': 281,
#  '声车': 282,
#  '小瓦要': 283,
#  '我斯开': 284,
#  '车热时': 285,
#  '克鲁斯': 286,
#  'b1517': 287,
#  '20604': 288,
#  '几钞钟': 289,
#  '长时间': 290,
#  '公家': 291,
#  '104.76': 292,
#  '感謝': 293,
#  'boost': 294,
#  '负架': 295,
#  '怠素': 296,
#  '厂点': 297,
#  '年海': 298,
#  '近光灯': 299,
#  'srx10': 300,
#  '方亲': 301,
#  'B10A915': 302,
#  '陈亚涛': 303,
#  '蠢蠢欲动': 304,
#  '换过去': 305,
#  '比迈锐': 306,
#  'sc7': 307,
#  '受卡': 308,
#  '换得油': 309,
#  '拉屎': 310,
#  '踩得': 311,
#  '死': 312,
#  '东风公司': 313,
#  '发向': 314,
#  '城市道路': 315,
#  '猛然': 316,
#  '330ev': 317,
#  '清醒': 318,
#  '里线': 319,
#  '冼剂': 320,
#  '插回来': 321,
#  '按中键': 322,
#  '此灯': 323,
#  '行进': 324,
#  '有马': 325,
#  '还敢': 326,
#  'Bose': 327,
#  'xieyi': 328,
#  '小妞': 329,
#  '买下': 330,
#  '火源': 331,
#  '靠不住': 332,
#  '抽压': 333,
#  'RNA': 334,
#  '再拉点': 335,
#  '相结合': 336,
#  '抛到': 337,
#  '装是': 338,
#  '灯响': 339,
#  '魏': 340,
#  '先复': 341,
#  '多过': 342,
#  'HSE': 343,
#  '粘有': 344,
#  '光坏': 345,
#  '第三方': 346,
#  '遇坑': 347,
#  '无虚接': 348,
#  '修机': 349,
#  '去拉下': 350,
#  '2.3': 351,
#  '改不了': 352,
#  '出应': 353,
#  '大费': 354,
#  '105D': 355,
#  '大得': 356,
#  'p2188': 357,
#  '款智骋': 358,
#  '电就开': 359,
#  '变认': 360,
#  '泡时': 361,
#  '嗽': 362,
#  '括号': 363,
#  '汴德宝': 364,
#  '碧云': 365,
#  '成多大': 366,
#  '磕起': 367,
#  '挡后': 368,
#  '总控': 369,
#  '久留': 370,
#  '指四滤': 371,
#  '又费': 372,
#  'JL': 373,
#  '拖拖': 374,
#  '可上': 375,
#  '不连贯': 376,
#  '那旧': 377,
#  '棉破': 378,
#  '雷凌撞': 379,
#  '9870': 380,
#  '没拉过': 381,
#  '网盘': 382,
#  'L91': 383,
#  '下途观': 384,
#  '破旧': 385,
#  '打冲': 386,
#  '走街串巷': 387,
#  '会溢水': 388,
#  '除雾器': 389,
#  '接都': 390,
#  '短是': 391,
#  '出抖': 392,
#  '华普海迅': 393,
#  '石角': 394,
#  '防碍': 395,
#  '薄不薄': 396,
#  'SH15w6D1': 397,
#  '选大五速': 398,
#  '掉常': 399,
#  '棚布': 400,
#  '焦皮': 401,
#  '数为': 402,
#  '撞墙': 403,
#  '收过': 404,
#  '毛皮': 405,
#  '爆振加': 406,
#  '几圈': 407,
#  '牵引力': 408,
#  '档绳': 409,
#  '保存起来': 410,
#  '钳响': 411,
#  '灯弄亮': 412,
#  '增器': 413,
#  '脂肪': 414,
#  '宝莱车': 415,
#  '发耸': 416,
#  '現在連': 417,
#  '迈给': 418,
#  '伴轴': 419,
#  '红桥': 420,
#  '要说': 421,
#  '以便': 422,
#  '我吸': 423,
#  '室盖面': 424,
#  '哈齿': 425,
#  '缺防动液': 426,
#  '高尔正时': 427,
#  '变压': 428,
#  '焕然一新': 429,
#  '基础': 430,
#  '出大团': 431,
#  '汽泵': 432,
#  '按不响': 433,
#  'Euc': 434,
#  '速高': 435,
#  '不': 436,
#  '轮点': 437,
#  '挂件': 438,
#  '4wd': 439,
#  '祝燃剂': 440,
#  '四位数': 441,
#  '康耐斯': 442,
#  '透雾': 443,
#  '加广': 444,
#  '搭拉': 445,
#  '以里': 446,
#  '前横撞': 447,
#  '三十二三': 448,
#  '来句': 449,
#  '钢板': 450,
#  '几口': 451,
#  '这位': 452,
#  '天冷顶': 453,
#  '普遍性': 454,
#  '真理': 455,
#  '235': 456,
#  '象断': 457,
#  '三五万': 458,
#  '看大泵': 459,
#  '拖能': 460,
#  '不松涨': 461,
#  '猛轰油': 462,
#  '欧歌报': 463,
#  '店太多': 464,
#  '人接': 465,
#  'h30cross2012': 466,
#  '高就响': 467,
#  '套筒': 468,
#  '十多公里': 469,
#  '塞纳': 470,
#  '急死了': 471,
#  '搭铁要': 472,
#  '答': 473,
#  '试吓': 474,
#  '众众': 475,
#  '哪调': 476,
#  '2017.12': 477,
#  '拍个阀': 478,
#  '数首': 479,
#  '易清洗': 480,
#  '放空': 481,
#  '志俊前': 482,
#  '典藏版': 483,
#  '果': 484,
#  '外凸': 485,
#  '150mA': 486,
#  '因起': 487,
#  '一百次': 488,
#  '给查': 489,
#  '必做': 490,
#  '进右': 491,
#  '下溜': 492,
#  '出事': 493,
#  '无源惠威': 494,
#  '清空': 495,
#  '1000.10': 496,
#  '格加': 497,
#  '舱内': 498,
#  '订金': 499,
#  '款中': 500,
#  '6376nf.2012': 501,
#  '换响': 502,
#  'SAVE': 503,
#  '左半': 504,
#  '心冲': 505,
#  '炮箱': 506,
#  '只右': 507,
#  '雅格': 508,
#  '克车': 509,
#  '最多': 510,
#  '1.07': 511,
#  '规矩': 512,
#  '不一而足': 513,
#  '涂点': 514,
#  '跑动': 515,
#  '转角处': 516,
#  '会照': 517,
#  '估计值': 518,
#  '87683': 519,
#  '有咚': 520,
#  '插死': 521,
#  '邓绿普口': 522,
#  '乔报': 523,
#  '提早': 524,
#  '量计算': 525,
#  '图二': 526,
#  '两小': 527,
#  'Gls450': 528,
#  '確': 529,
#  '金平': 530,
#  '讲问': 531,
#  '下别': 532,
#  '净水': 533,
#  '两名': 534,
#  '不可': 535,
#  '主板': 536,
#  '5W20': 537,
#  '320000': 538,
#  '要小众': 539,
#  '再放车': 540,
#  '浮潜时': 541,
#  '出沟': 542,
#  '高先': 543,
#  '店内用': 544,
#  '大汉': 545,
#  '会亏': 546,
#  'Cd510': 547,
#  '1497': 548,
#  '分浆': 549,
#  '对太压': 550,
#  '虑': 551,
#  '盘才': 552,
#  '怠速开': 553,
#  '妨碍': 554,
#  '冻烂': 555,
#  '幅漆': 556,
#  '压标': 557,
#  '拆路': 558,
#  '后标': 559,
#  '啧上': 560,
#  '电桥': 561,
#  '极客': 562,
#  '在我看来': 563,
#  '比磁护': 564,
#  '数偏': 565,
#  '测一': 566,
#  '焦急': 567,
#  '完再排': 568,
#  '补二': 569,
#  'c5013': 570,
#  '肥胖': 571,
#  '暴躁': 572,
#  '下会响': 573,
#  '这次': 574,
#  '接机': 575,
#  '三角形': 576,
#  '威': 577,
#  'Ram': 578,
#  '失业': 579,
#  '贯': 580,
#  '菱箱': 581,
#  '过滥路': 582,
#  '异响法': 583,
#  '亚光': 584,
#  '蒙在鼓里': 585,
#  '油急': 586,
#  '槽口': 587,
#  '方框框': 588,
#  '局限': 589,
#  'W204': 590,
#  '升对': 591,
#  'e63amg': 592,
#  '做放气': 593,
#  '完折': 594,
#  '建和调': 595,
#  '新动力': 596,
#  '线控': 597,
#  '中剎车': 598,
#  '32008': 599,
#  '有孔': 600,
#  'P0191': 601,
#  '内存条': 602,
#  '担心': 603,
#  '闸阀': 604,
#  '取起': 605,
#  '将付': 606,
#  '那层': 607,
#  '最顶配': 608,
#  's40': 609,
#  '款新悦翔': 610,
#  '罐到': 611,
#  '起电': 612,
#  '617339': 613,
#  'ON': 614,
#  '乏': 615,
#  '后桥加': 616,
#  '街道': 617,
#  '看划': 618,
#  '调机': 619,
#  '厢前': 620,
#  '支护': 621,
#  '变箱': 622,
#  '换挺筒': 623,
#  '喘息声': 624,
#  '器有': 625,
#  '个片': 626,
#  '没电不报': 627,
#  '汽车电机': 628,
#  '轰完': 629,
#  '卵': 630,
#  'RPN': 631,
#  '声称': 632,
#  '路霸': 633,
#  '2.32': 634,
#  '简拿': 635,
#  '距话': 636,
#  '不堪设想': 637,
#  '外饰': 638,
#  '较少': 639,
#  '压架': 640,
#  '1387075': 641,
#  '汽吧': 642,
#  '沸腾': 643,
#  '164000': 644,
#  '26233': 645,
#  '062': 646,
#  '吃力': 647,
#  '锁快': 648,
#  '姚贝': 649,
#  '板右': 650,
#  '起大': 651,
#  '异音': 652,
#  '2013.7': 653,
#  '255': 654,
#  '劳务费': 655,
#  '打散': 656,
#  '有词': 657,
#  '刮粉': 658,
#  '用车': 659,
#  '车电': 660,
#  '不动时': 661,
#  '刘换': 662,
#  '出故': 663,
#  'r350': 664,
#  '盘拿去': 665,
#  '大君': 666,
#  '购机': 667,
#  '过烂': 668,
#  '过手': 669,
#  '有个键': 670,
#  '不补': 671,
#  '喷剂': 672,
#  '款美规': 673,
#  '万过': 674,
#  '封锁': 675,
#  '董': 676,
#  '时负': 677,
#  '共震要': 678,
#  '一個': 679,
#  '開到': 680,
#  '试来': 681,
#  '没扎': 682,
#  '刻着': 683,
#  '平亮': 684,
#  '这九跟线': 685,
#  '你会接': 686,
#  '7mm': 687,
#  '接负': 688,
#  '尊行': 689,
#  'y': 690,
#  '细簧': 691,
#  '裸车': 692,
#  '火车站': 693,
#  '0.43': 694,
#  '漏斗状': 695,
#  '改缸': 696,
#  '谈不拢': 697,
#  '看待': 698,
#  '驾窗': 699,
#  'dxl2': 700,
#  '肉痛': 701,
#  '威驰车': 702,
#  '点不开': 703,
#  '不动雨': 704,
#  '回错': 705,
#  '比作': 706,
#  '挺久': 707,
#  'a8L4.0': 708,
#  '不灵敏': 709,
#  '亮量': 710,
#  '钢后': 711,
#  '纳米布': 712,
#  '自然损耗': 713,
#  '中以': 714,
#  '记录器': 715,
#  '下坠': 716,
#  '欠佳': 717,
#  '伪劣产品': 718,
#  '766309': 719,
#  'ESC': 720,
#  '车所要': 721,
#  '脆弱': 722,
#  '关右': 723,
#  'KKK': 724,
#  '扼杀': 725,
#  'mqb': 726,
#  '饿车': 727,
#  '冷剂': 728,
#  '油价格': 729,
#  '星全车': 730,
#  '大把大把': 731,
#  '市场需求': 732,
#  '改上': 733,
#  '全不全': 734,
#  '只脱': 735,
#  '全付': 736,
#  '13308693': 737,
#  '用火燎': 738,
#  '手环': 739,
#  '某家': 740,
#  'O型': 741,
#  '萨姆': 742,
#  '01512': 743,
#  'ws': 744,
#  '接待': 745,
#  '重买': 746,
#  '03C906433': 747,
#  '多屏': 748,
#  '管从': 749,
#  '豪叫': 750,
#  '指四驱': 751,
#  '12.23': 752,
#  '会半': 753,
#  '轰轰': 754,
#  '拆不上': 755,
#  '1085423': 756,
#  '防爆膜': 757,
#  '咖版': 758,
#  '大连市': 759,
#  '蜡后': 760,
#  '元及': 761,
#  '装张': 762,
#  '地确': 763,
#  '半右': 764,
#  'P07A3': 765,
#  '车内': 766,
#  '用交': 767,
#  '长叫': 768,
#  '刚产': 769,
#  '光后': 770,
#  '十二点': 771,
#  '桉': 772,
#  '谢样': 773,
#  '直用': 774,
#  '不滑': 775,
#  '千车': 776,
#  '力费油': 777,
#  '填点': 778,
#  'P0017': 779,
#  '下格': 780,
#  '油减': 781,
#  '火力': 782,
#  '货箱': 783,
#  '尺就够': 784,
#  '误起': 785,
#  '不太脏': 786,
#  '装时': 787,
#  '100km': 788,
#  '占便宜': 789,
#  '车炸': 790,
#  '及脚': 791,
#  '不拖底': 792,
#  '起油': 793,
#  'H2s': 794,
#  '厚点': 795,
#  '再七升': 796,
#  '随及': 797,
#  '明儿': 798,
#  'A13RS': 799,
#  '引机震': 800,
#  '6376NF1.0': 801,
#  '礼县': 802,
#  '棉车': 803,
#  '全不不动': 804,
#  '西雅特': 805,
#  '他会': 806,
#  '乱晃': 807,
#  '越供': 808,
#  '毁灭': 809,
#  '已不抖': 810,
#  '会灭车': 811,
#  '要响': 812,
#  '天池': 813,
#  '双条': 814,
#  '能锁主': 815,
#  '11V': 816,
#  '14272': 817,
#  '前氧和后': 818,
#  '姑父': 819,
#  '水可补': 820,
#  '不太费油': 821,
#  '0.59': 822,
#  '懂来': 823,
#  '可大可小': 824,
#  '车化': 825,
#  '11MPH': 826,
#  '噶资噶资': 827,
#  '再度': 828,
#  '改出': 829,
#  '棉流': 830,
#  '迅箱': 831,
#  '好几位': 832,
#  '开四': 833,
#  '椐': 834,
#  '热风枪': 835,
#  '日右': 836,
#  '635': 837,
#  '99.22%': 838,
#  '先食': 839,
#  '改良版': 840,
#  '卡滯': 841,
#  '隔车点': 842,
#  '当刚': 843,
#  '6376NF12': 844,
#  '没电会': 845,
#  '触感': 846,
#  '派出': 847,
#  '断电器': 848,
#  'omv': 849,
#  'u0001': 850,
#  '要练': 851,
#  's6391': 852,
#  '体已': 853,
#  '引患': 854,
#  '后盖板': 855,
#  '掰断': 856,
#  '多松点': 857,
#  '车脏': 858,
#  '四驱开': 859,
#  '打近': 860,
#  '睹': 861,
#  '寄回': 862,
#  '有待于': 863,
#  '热会车': 864,
#  '调反': 865,
#  '店补漆': 866,
#  '坐下': 867,
#  '62240': 868,
#  '后氧拔': 869,
#  'C0287': 870,
#  '换锁架': 871,
#  '多练': 872,
#  '万应': 873,
#  '接是': 874,
#  '卡试': 875,
#  '健件': 876,
#  '95.0': 877,
#  '追求': 878,
#  '普通话': 879,
#  '测大线': 880,
#  '急不来': 881,
#  '使启停': 882,
#  '能撑': 883,
#  '回抖': 884,
#  '台束': 885,
#  '挺累': 886,
#  '除油表': 887,
#  '孟': 888,
#  '距首保': 889,
#  '人看': 890,
#  '1K0': 891,
#  '3w': 892,
#  '车套': 893,
#  't500': 894,
#  '会显': 895,
#  '风圈': 896,
#  '搜有': 897,
#  '有躁': 898,
#  '停不下来': 899,
#  '接住': 900,
#  '左灯': 901,
#  '小弟': 902,
#  '存水': 903,
#  '减少': 904,
#  '经得住': 905,
#  '跟玛': 906,
#  '贫化': 907,
#  '款哈弗': 908,
#  '威达电': 909,
#  '回拉': 910,
#  '中距离': 911,
#  '随转': 912,
#  'LOWWASH': 913,
#  '乱串': 914,
#  '别溅': 915,
#  '比起': 916,
#  '装饰灯': 917,
#  '中肯': 918,
#  '一拉看': 919,
#  '威跑': 920,
#  '以换': 921,
#  '保盒': 922,
#  '曼排': 923,
#  '有帘线': 924,
#  '丢尺': 925,
#  '款翼博': 926,
#  '堵掉': 927,
#  '重用': 928,
#  '陈哒': 929,
#  '手平托': 930,
#  '一趟': 931,
#  '挡测': 932,
#  '218': 933,
#  '改停': 934,
#  '考来': 935,
#  '会崩断': 936,
#  'f50a': 937,
#  '燈罩': 938,
#  '不胎': 939,
#  '大众汽车': 940,
#  '剂来': 941,
#  '如着': 942,
#  '请况': 943,
#  '岳父': 944,
#  '325E90': 945,
#  '画框': 946,
#  '抓出': 947,
#  '6376C3': 948,
#  '而定': 949,
#  'motul': 950,
#  '座球头': 951,
#  '热越': 952,
#  '焊长': 953,
#  '六键会': 954,
#  '走到': 955,
#  '或卡兹': 956,
#  '上海大众': 957,
#  '帘用': 958,
#  '车撞': 959,
#  '静时': 960,
#  '架空': 961,
#  '拆下们': 962,
#  '那不带': 963,
#  '勾上': 964,
#  '劳动': 965,
#  '写过': 966,
#  '突圆': 967,
#  '脱位': 968,
#  '焊铝': 969,
#  '集气': 970,
#  '15.4': 971,
#  '六点钟': 972,
#  'cx70t': 973,
#  '稳压器': 974,
#  '你告': 975,
#  '丢油响': 976,
#  '连铁': 977,
#  '缸内': 978,
#  '故障': 979,
#  '郑': 980,
#  '后抖': 981,
#  '条海福莱': 982,
#  '14037483': 983,
#  '太浅': 984,
#  '挣上': 985,
#  'z700h': 986,
#  '链壳': 987,
#  'fo11': 988,
#  '后翼': 989,
#  '拼错': 990,
#  '没锈': 991,
#  '卸压': 992,
#  '逃电': 993,
#  '万后': 994,
#  '卡中': 995,
#  '棚里': 996,
#  '水热': 997,
#  '通气孔': 998,
#  '机及': 999,
#  ...}
